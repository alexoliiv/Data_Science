# %% [markdown]
# <h1> In this notebook, I'll be using Linear Regression to predict house prices, different than the previous notebook, in this notebook I'll be working with multiple variables. </h1>

# %% [markdown]
# <h2> 1. Libraries </h2>

# %%
import numpy as np
import matplotlib.pyplot as plt 

import pandas as pd  
import seaborn as sns 

# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# <h2> 2.Data Wrangling </h2>

# %%
# Gerando o dataset
boston = load_boston() 
dataset = pd.DataFrame(boston.data, columns = boston.feature_names)
dataset['target'] = boston.target

# %%
## Visualizar valores nulos por coluna
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# target     0
# dtype: int64

# %%
# Gerando número de observações e variáveis
observations = len(dataset)
variables = dataset.columns[:-1]

# %%
## Visualizing correlation between features and target
df_Corr = dataset.corr(method='spearman')

# %% [markdown]
# <h2> Visualyze Data </h2>

# %%
## Analyze target variable distribution
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(dataset['target'], bins=30)
plt.show()
# Out:
# C:\Users\alexander.leite\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
## analyze variables correlation
correlation_matrix = dataset.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)

# %%
correlation_matrix.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-225-77b9c17d25db> in <module>()
# ----> 1 correlation_matrix.sort_values()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
plt.figure(figsize=(20, 5))

features = ['LSTAT', 'RM','PTRATIO']
target = dataset['target']

for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = dataset[col]
    y = target
    plt.scatter(x, y, marker='o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('target')

# %%
## Dropping variables with high correlation using eigenvalues and eigenvector
eigenvalues, eigenvectors = np.linalg.eig(df_Corr)

# %%
print (eigenvalues)
# Out:
# [7.1702295  1.54013717 1.1209152  0.89012559 0.77563213 0.67589626
#  0.4789585  0.34893363 0.27297565 0.09049434 0.19707686 0.17200456
#  0.12155513 0.14506549]

# %%
print (eigenvectors[:,8])
# Out:
# [-0.10044427 -0.44028371  0.06263055  0.03516774 -0.11167895  0.49843661
#  -0.11388766  0.3184594  -0.02099362  0.22473825 -0.3618146   0.08371022
#   0.26135441 -0.39803575]

# %%
print (variables[2], variables[8], variables[9])
# Out:
# INDUS RAD TAX

# %%
dataset = dataset.drop([variables[2], variables[8], variables[9]],axis=1)

# %% [markdown]
# <h2> Gradient Descent </h2>

# %%
# Coletando x e y
X = pd.DataFrame(np.c_[dataset['LSTAT'], dataset['RM'],dataset['PTRATIO']], columns = ['LSTAT','RM','PTRATIO'])
##X = dataset.iloc[:,:-1]
y = dataset['target']

# %%
rescaledX = preprocessing.scale(X)
rescaledy = preprocessing.scale(y)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(rescaledX, rescaledy, test_size = 0.2, random_state=5)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (404, 2)
# (102, 2)
# (404,)
# (102,)

# %%
x = np.c_[np.ones(X_train.shape[0]),X_train]
y = Y_train

# %%
# Parameters required for Gradient Descent
alpha = 0.0001   #learning rate
m = y.size  #no. of samples
np.random.seed(10)
theta = np.random.rand(4)  #initializing theta with some random values
iterations = 100000

# %%
def gradient_descent(x, y, m, theta, alpha):
    cost_list = []   #to record all cost values to this list
    theta_list = []  #to record all theta_0 and theta_1 values to this list 
    prediction_list = []
    run = True
    cost_list.append(1e10)    #we append some large value to the cost list
    i=0
    while run:
        prediction = np.dot(x, theta)   #predicted y values theta_0*x0+theta_1*x1
        prediction_list.append(prediction)
        error = prediction - y
        cost = 1/(2*m) * np.dot(error.T, error)   #  (1/2m)*sum[(error)^2]
        cost_list.append(cost)
        theta = theta - (alpha * (1/m) * np.dot(x.T, error))   # alpha * (1/m) * sum[error*x]
        theta_list.append(theta)
        if cost_list[i]-cost_list[i+1] < 1e-9:   #checking if the change in cost function is less than 10^(-9)
            run = False

        i+=1
    cost_list.pop(0)   # Remove the large number we added in the begining 
    return prediction_list, cost_list, theta_list

# %%
prediction_list, cost_list, theta_list = gradient_descent(x, y, m, theta, alpha)

# %%
plt.title('Cost Function J', size = 30)
plt.xlabel('No. of iterations', size=20)
plt.ylabel('Cost', size=20)
plt.plot(cost_list)
plt.show()

# %%
theta_list[-1:]
# Out:
# [array([-0.00452731, -0.49696969,  0.30482373, -0.22452435])]

# %%
theta = theta_list[-1:]

# %%
lin_model = LinearRegression()
lin_model.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lin_model.intercept_ = theta[0][0]
lin_model.coef_ = np.c_[np.array(theta[0][1]),np.array(theta[0][2]),np.array(theta[0][3])]

# %%
print(lin_model.intercept_)
print(lin_model.coef_)
# Out:
# -0.004527307441895949
# [[-0.49696969  0.30482373 -0.22452435]]

# %%
# model evaluation for training set
y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 0.5772803173417055
# R2 score is 0.672497349825522

# %%
# model evaluation for testing set
y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for testing set
# --------------------------------------
# RMSE is 0.5327777846525711
# R2 score is 0.6939393286112943
