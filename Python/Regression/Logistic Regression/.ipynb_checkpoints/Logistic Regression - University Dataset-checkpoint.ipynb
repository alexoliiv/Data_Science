# %% [markdown]
# <h2> In this notebook, I'll use Logistic Regression to predict wheter a student gets
# admitted into a university. </h2>

# %% [markdown]
# <h2> 1. Libraries </h2>

# %%
import numpy as np
import matplotlib.pyplot as plt 

import pandas as pd  
import seaborn as sns 

# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report


from imblearn.over_sampling import SMOTE

# %% [markdown]
# <h2> 2.Data Wrangling </h2>

# %%
path= "C:\\Users\\alexander.leite\\Desktop\Machine Learning\\datasets\ex2data.txt"

# %%
Df_grades = pd.read_csv(path, sep=",", header=None)
Df_grades.columns = ['Grade 1','Grade 2','Approved']

# %%
Df_grades
# Out:
#       Grade 1    Grade 2  Approved
# 0   34.623660  78.024693         0
# 1   30.286711  43.894998         0
# 2   35.847409  72.902198         0
# 3   60.182599  86.308552         1
# 4   79.032736  75.344376         1
# 5   45.083277  56.316372         0
# 6   61.106665  96.511426         1
# 7   75.024746  46.554014         1
# 8   76.098787  87.420570         1
# 9   84.432820  43.533393         1
# 10  95.861555  38.225278         0
# 11  75.013658  30.603263         0
# 12  82.307053  76.481963         1
# 13  69.364589  97.718692         1
# 14  39.538339  76.036811         0
# 15  53.971052  89.207350         1
# 16  69.070144  52.740470         1
# 17  67.946855  46.678574         0
# 18  70.661510  92.927138         1
# 19  76.978784  47.575964         1
# 20  67.372028  42.838438         0
# 21  89.676776  65.799366         1
# 22  50.534788  48.855812         0
# 23  34.212061  44.209529         0
# 24  77.924091  68.972360         1
# 25  62.271014  69.954458         1
# ...

# %%
decimals = pd.Series([2,2],index=['Grade 1','Grade 2'])
Df_grades.round(decimals)
# Out:
#     Grade 1  Grade 2  Approved
# 0     34.62    78.02         0
# 1     30.29    43.89         0
# 2     35.85    72.90         0
# 3     60.18    86.31         1
# 4     79.03    75.34         1
# 5     45.08    56.32         0
# 6     61.11    96.51         1
# 7     75.02    46.55         1
# 8     76.10    87.42         1
# 9     84.43    43.53         1
# 10    95.86    38.23         0
# 11    75.01    30.60         0
# 12    82.31    76.48         1
# 13    69.36    97.72         1
# 14    39.54    76.04         0
# 15    53.97    89.21         1
# 16    69.07    52.74         1
# 17    67.95    46.68         0
# 18    70.66    92.93         1
# 19    76.98    47.58         1
# 20    67.37    42.84         0
# 21    89.68    65.80         1
# 22    50.53    48.86         0
# 23    34.21    44.21         0
# 24    77.92    68.97         1
# 25    62.27    69.95         1
# 26    80.19    44.82         1
# 27    93.11    38.80         0
# 28    61.83    50.26         0
# ...

# %%
positive = Df_grades[Df_grades['Approved']==1]
negative = Df_grades[Df_grades['Approved']==0]

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(positive['Grade 1'], positive['Grade 2'], s=50, c='b', marker='o', label='Admitted')
ax.scatter(negative['Grade 1'], negative['Grade 2'], s=50, c='r', marker='x', label='Not Admitted')
ax.legend()
ax.set_xlabel('Exam 1 Score')
ax.set_ylabel('Exam 2 Score')
# Out:
# Text(0,0.5,'Exam 2 Score')

# %%
Df_grades.isnull().sum()
# Out:
# Grade 1     0
# Grade 2     0
# Approved    0
# dtype: int64

# %%
Df_grades.describe()
# Out:
#           Grade 1     Grade 2    Approved
# count  100.000000  100.000000  100.000000
# mean    65.644274   66.221998    0.600000
# std     19.458222   18.582783    0.492366
# min     30.058822   30.603263    0.000000
# 25%     50.919511   48.179205    0.000000
# 50%     67.032988   67.682381    1.000000
# 75%     80.212529   79.360605    1.000000
# max     99.827858   98.869436    1.000000

# %%
Df_grades['Approved'].value_counts()
# Out:
# 1    60
# 0    40
# Name: Approved, dtype: int64

# %%
nTotal = len(Df_grades)
nApproved = len(Df_grades[Df_grades['Approved'] == 1])
nNotApproved = len(Df_grades[Df_grades['Approved'] == 0])

# %%
print("Approved Students: ", (nApproved /nTotal) * 100,"%")
print("Disapproved Students: ", (nNotApproved /nTotal) * 100,"%")
# Out:
# Approved Students:  60.0 %
# Disapproved Students:  40.0 %

# %%
X = Df_grades.iloc[:,:-1]
X.head()
# Out:
#      Grade 1    Grade 2
# 0  34.623660  78.024693
# 1  30.286711  43.894998
# 2  35.847409  72.902198
# 3  60.182599  86.308552
# 4  79.032736  75.344376

# %%
y = Df_grades['Approved']
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1
# Name: Approved, dtype: int64

# %%
os = SMOTE(random_state=0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
columns = X_train.columns

# %%
os_data_X,os_data_y=os.fit_sample(X_train, y_train)
os_data_X = pd.DataFrame(data=os_data_X,columns=columns )
os_data_y= pd.DataFrame(data=os_data_y,columns=['y'])
# we can Check the numbers of our data
print("length of oversampled data is ",len(os_data_X))
print("Number of no subscription in oversampled data",len(os_data_y[os_data_y['y']==0]))
print("Number of subscription",len(os_data_y[os_data_y['y']==1]))
print("Proportion of no subscription data in oversampled data is ",len(os_data_y[os_data_y['y']==0])/len(os_data_X))
print("Proportion of subscription data in oversampled data is ",len(os_data_y[os_data_y['y']==1])/len(os_data_X))
# Out:
# length of oversampled data is  82
# Number of no subscription in oversampled data 41
# Number of subscription 41
# Proportion of no subscription data in oversampled data is  0.5
# Proportion of subscription data in oversampled data is  0.5

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# C:\Users\alexander.leite\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.90

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[ 8  3]
#  [ 0 19]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.73      0.84        11
#            1       0.86      1.00      0.93        19
#
#    micro avg       0.90      0.90      0.90        30
#    macro avg       0.93      0.86      0.88        30
# weighted avg       0.91      0.90      0.90        30
